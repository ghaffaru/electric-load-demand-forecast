# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('hourly 2018.csv')

# %%
data.head()
# Out:
#   HOURLY LOAD FORECAST 2018 Unnamed: 1 Unnamed: 2   Unnamed: 3 Unnamed: 4  \
# 0                    MONTHS       DAYS      HOURS  TEMPERATURE   HUMIDITY
# 1                         1          1          1           22       68.2
# 2                         1          1          2        21.66       67.3
# 3                         1          1          3        21.18       67.8
# 4                         1          1          4        19.77      67.15
#
#           Unnamed: 5
# 0  HISTORIC LOAD(MW)
# 1                8.4
# 2                8.3
# 3                8.3
# 4                7.6

# %%
data.iloc[0]
# Out:
# HOURLY LOAD FORECAST 2018               MONTHS
# Unnamed: 1                                DAYS
# Unnamed: 2                               HOURS
# Unnamed: 3                         TEMPERATURE
# Unnamed: 4                            HUMIDITY
# Unnamed: 5                   HISTORIC LOAD(MW)
# Name: 0, dtype: object

# %%
data.columns = data.iloc[0]

# %%
data
# Out:
# 0    MONTHS  DAYS  HOURS  TEMPERATURE  HUMIDITY  HISTORIC LOAD(MW)
# 0    MONTHS  DAYS  HOURS  TEMPERATURE  HUMIDITY  HISTORIC LOAD(MW)
# 1         1     1      1           22      68.2                8.4
# 2         1     1      2        21.66      67.3                8.3
# 3         1     1      3        21.18      67.8                8.3
# 4         1     1      4        19.77     67.15                7.6
# ..      ...   ...    ...          ...       ...                ...
# 212       3     3     20        30.68     68.45               12.9
# 213       3     3     21        28.77      78.4               13.1
# 214       3     3     22        28.07      78.4               12.6
# 215       3     3     23        27.36      79.8               11.3
# 216       3     3     24        26.87      51.2                9.5
#
# [217 rows x 6 columns]

# %%
data.drop([0], inplace=True)

# %%
data
# Out:
# 0   MONTHS DAYS HOURS TEMPERATURE HUMIDITY HISTORIC LOAD(MW)
# 1        1    1     1          22     68.2               8.4
# 2        1    1     2       21.66     67.3               8.3
# 3        1    1     3       21.18     67.8               8.3
# 4        1    1     4       19.77    67.15               7.6
# 5        1    1     5       19.45     68.8               7.6
# ..     ...  ...   ...         ...      ...               ...
# 212      3    3    20       30.68    68.45              12.9
# 213      3    3    21       28.77     78.4              13.1
# 214      3    3    22       28.07     78.4              12.6
# 215      3    3    23       27.36     79.8              11.3
# 216      3    3    24       26.87     51.2               9.5
#
# [216 rows x 6 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 216 entries, 1 to 216
# Data columns (total 6 columns):
# MONTHS               216 non-null object
# DAYS                 216 non-null object
# HOURS                216 non-null object
# TEMPERATURE          216 non-null object
# HUMIDITY             216 non-null object
# HISTORIC LOAD(MW)    216 non-null object
# dtypes: object(6)
# memory usage: 11.8+ KB

# %%
data['MONTHS'] = data['MONTHS'].astype(float)
data['TEMPERATURE'] = data['TEMPERATURE'].astype(float)
data['DAYS'] = data['DAYS'].astype(float)
data['HUMIDITY'] = data['HUMIDITY'].astype(float)
data['HOURS'] = data['HOURS'].astype(float)
data['HISTORIC LOAD(MW)'] = data['HISTORIC LOAD(MW)'].astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 216 entries, 1 to 216
# Data columns (total 6 columns):
# MONTHS               216 non-null float64
# DAYS                 216 non-null float64
# HOURS                216 non-null float64
# TEMPERATURE          216 non-null float64
# HUMIDITY             216 non-null float64
# HISTORIC LOAD(MW)    216 non-null float64
# dtypes: float64(6)
# memory usage: 11.8 KB

# %%
data.describe()
# Out:
# 0          MONTHS        DAYS       HOURS  TEMPERATURE   HUMIDITY  \
# count  216.000000  216.000000  216.000000   216.000000  216.00000
# mean     2.000000    2.000000   12.500000    27.232315   60.92588
# std      0.818393    0.818393    6.938266     4.350881   19.44699
# min      1.000000    1.000000    1.000000    18.880000   22.80000
# 25%      1.000000    1.000000    6.750000    23.962500   47.23750
# 50%      2.000000    2.000000   12.500000    27.035000   63.50000
# 75%      3.000000    3.000000   18.250000    30.780000   74.55000
# max      3.000000    3.000000   24.000000    35.660000   94.30000
#
# 0      HISTORIC LOAD(MW)
# count         216.000000
# mean            9.671852
# std             1.417885
# min             6.700000
# 25%             8.675000
# 50%             9.450000
# 75%            10.300000
# max            13.200000

# %%
data.columns
# Out:
# Index(['MONTHS', 'DAYS', 'HOURS', 'TEMPERATURE', 'HUMIDITY',
#        'HISTORIC LOAD(MW)'],
#       dtype='object', name=0)

# %%
plt.plot(data['HOURS'], data['TEMPERATURE'])

# %%
plt.figure(figsize=(20,10))
sns.heatmap(data.corr(), annot=True)

# %%
plt.scatter(data[['HOURS']], data[['TEMPERATURE']])
plt.xlabel('HOURS')
plt.ylabel('TEMPERATURE')
# Out:
# Text(0,0.5,'TEMPERATURE')

# %%
plt.scatter(data[['HOURS']], data[['HUMIDITY']])
plt.xlabel('HOURS')
plt.ylabel('HUMIDITY')
# Out:
# Text(0,0.5,'HUMIDITY')

# %%
#hours against historic load
plt.scatter(data[['HOURS']], data[['HISTORIC LOAD(MW)']])
plt.xlabel('HOURS')
plt.ylabel('HISTORIC LOAD(MW)')
# Out:
# Text(0,0.5,'HISTORIC LOAD(MW)')

# %%
#January 2018 data analysis
day_one = data[data['MONTHS'] == 1][data[data['MONTHS'] == 1]['DAYS'] == 1]

# %%
day_one
# Out:
# 0   MONTHS  DAYS  HOURS  TEMPERATURE  HUMIDITY  HISTORIC LOAD(MW)
# 1      1.0   1.0    1.0        22.00     68.20                8.4
# 2      1.0   1.0    2.0        21.66     67.30                8.3
# 3      1.0   1.0    3.0        21.18     67.80                8.3
# 4      1.0   1.0    4.0        19.77     67.15                7.6
# 5      1.0   1.0    5.0        19.45     68.80                7.6
# 6      1.0   1.0    6.0        19.19     58.75                7.6
# 7      1.0   1.0    7.0        18.88     53.50                6.8
# 8      1.0   1.0    8.0        19.71     48.30                6.7
# 9      1.0   1.0    9.0        21.77     42.16                6.9
# 10     1.0   1.0   10.0        24.31     35.90                7.1
# 11     1.0   1.0   11.0        26.38     35.50                7.4
# 12     1.0   1.0   12.0        28.21     33.30                7.7
# 13     1.0   1.0   13.0        30.65     28.05                7.7
# ...

# %%
plt.plot(day_one['HOURS'], day_one['HISTORIC LOAD(MW)'])
plt.show()

# %%
day_two = data[data['MONTHS'] == 1][data[data['MONTHS'] == 1]['DAYS'] == 2]

# %%
plt.plot(day_two['HOURS'], day_two['HISTORIC LOAD(MW)'])
plt.show()

# %%
day_three = data[data['MONTHS'] == 1][data[data['MONTHS'] == 1]['DAYS'] == 3]

# %%
plt.plot(day_three['HOURS'], day_three['HISTORIC LOAD(MW)'])
plt.xlabel('HOURS')
plt.ylabel('LOAD (MW)')
plt.show()

# %%
#February data Analysis
feb_day_one = data[data['MONTHS'] == 2][data[data['MONTHS'] == 2]['DAYS'] == 1]

# %%
plt.plot(day_three['HOURS'], day_three['HISTORIC LOAD(MW)'])
plt.show()

# %%
january_data = data[data['MONTHS'] == 1]

# %%
#January data
plt.figure(figsize=(20,10))
plt.plot(january_data['HOURS'], january_data['HISTORIC LOAD(MW)'],'r')
plt.show()

# %%
#February data
february_data = data[data['MONTHS'] == 2]
plt.figure(figsize=(20,10))
plt.plot(february_data['HOURS'], february_data['HISTORIC LOAD(MW)'],'g')
plt.show()

# %%
#march data
march_data = data[data['MONTHS'] == 3]
plt.figure(figsize=(20,10))
plt.plot(march_data['HOURS'], march_data['HISTORIC LOAD(MW)'],'b')
plt.show()

# %%
plt.figure(figsize=(20,12))
plt.plot(data[data['MONTHS'] == 1]['HOURS'] , data[data['MONTHS'] == 1]['HISTORIC LOAD(MW)'])
plt.plot(data[data['MONTHS'] == 2]['HOURS'] , data[data['MONTHS'] == 2]['HISTORIC LOAD(MW)'])
plt.plot(data[data['MONTHS'] == 3]['HOURS'] , data[data['MONTHS'] == 3]['HISTORIC LOAD(MW)'])
plt.legend(['January 2018','February 2018', 'March 2018'])
plt.xlabel('Hours')
plt.ylabel('Historic load')
plt.grid(True)
plt.show()

# %%
data.columns
# Out:
# Index(['MONTHS', 'DAYS', 'HOURS', 'TEMPERATURE', 'HUMIDITY',
#        'HISTORIC LOAD(MW)'],
#       dtype='object', name=0)

# %%
features = data[['HOURS','TEMPERATURE','DAYS','HUMIDITY','MONTHS']]
label = data[['HISTORIC LOAD(MW)']]

# %%
features.shape
# Out:
# (216, 5)

# %%
label.shape
# Out:
# (216, 1)

# %%
from sklearn.model_selection import train_test_split

# %%
features_train, features_test, label_train, label_test = train_test_split(features, label, test_size=0.1)

# %%
features_train.shape
# Out:
# (194, 5)

# %%
features_test.shape
# Out:
# (22, 5)

# %%
label_test.shape
# Out:
# (22, 1)

# %%
# from sklearn.svm import SVR
# from sklearn.linear_model import LinearRegression
from sklearn import tree

# %%
model = tree.DecisionTreeRegressor()

# %%
model.fit(features_train, label_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')

# %%
from sklearn.metrics import mean_squared_error

# %%
np.sqrt(mean_squared_error(label_test, model.predict(features_test)))
# Out:
# 0.40056777885215045

# %%
features_test.head()
# Out:
# 0    HOURS  TEMPERATURE  DAYS  HUMIDITY  MONTHS
# 205   13.0        33.02   3.0     53.60     3.0
# 2      2.0        21.66   1.0     67.30     1.0
# 87    15.0        34.47   1.0     45.80     2.0
# 74     2.0        25.21   1.0     65.05     2.0
# 89    17.0        34.72   1.0     41.60     2.0

# %%
label_test.head()
# Out:
# 0    HISTORIC LOAD(MW)
# 205                9.5
# 2                  8.3
# 87                10.0
# 74                 9.4
# 89                10.0

# %%
model.predict([features_test.loc[74
                                ]])
# Out:
# array([9.7])

# %%
# model.predict([features_test.loc[]])
from joblib import dump
model_import = dump(model,'decision_tree(0.49).joblib')

# %%
plt.figure(figsize=(20,10))
plt.plot(np.arange(1,23), label_test['HISTORIC LOAD(MW)'])
plt.plot(np.arange(1,23), model.predict(features_test))
plt.legend(['Actual','Predicted'])
plt.show()

# %%
from joblib import load

# %%
dump(model,'linear_r_hourly_4(0.859).joblib')

# %%
mod = load('.joblib')

# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'MONTHS' : 10,
    'DAYS' : 10,
    'HOURS' : 22,
    'TEMPERATURE' : 24.98,
    'HUMIDITY' : 40.1
}, index=[])
