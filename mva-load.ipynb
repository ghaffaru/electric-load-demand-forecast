# %%
from pyforest import *

# %%
data = pd.read_excel('august.xlsx')

# %%
data.columns = data.iloc[0]

# %%
data
# Out:
# 0                  Time  27T1 (MVA)  27T2 (MVA)  Total Station Load (MVA)  \
# 0                  Time  27T1 (MVA)  27T2 (MVA)  Total Station Load (MVA)
# 1   2015-04-01 01:00:00         9.2         6.5                      15.7
# 2   2015-04-01 02:00:00         8.8         6.1                      14.9
# 3   2015-04-01 03:00:00         8.7         6.1                      14.8
# 4   2015-04-01 04:00:00         8.7         6.1                      14.8
# 5   2015-04-01 05:00:00         9.8         6.5                      16.3
# 6   2015-04-01 06:00:00         9.1         5.9                        15
# 7   2015-04-01 07:00:00           9         5.9                      14.9
# 8   2015-04-01 08:00:00         9.3         6.4                      15.7
# 9   2015-04-01 09:00:00         9.4         6.5                      15.9
# 10  2015-04-01 10:00:00         7.7         6.8                      14.5
# 11  2015-04-01 11:00:00         8.2         6.9                      15.1
# ...

# %%
data.drop(0, inplace=True)

# %%
data['Total Station Load (MVA)']
# Out:
# 0  Total Station Load (MVA) Total Station Load (MVA) Total Station Load (MVA)  \
# 1                      15.7                     18.1                     17.7
# 2                      14.9                     17.1                     17.4
# 3                      14.8                     16.8                     17.4
# 4                      14.8                     16.9                     17.2
# 5                      16.3                       17                     16.3
# 6                        15                     18.1                     17.1
# 7                      14.9                     16.1                     15.2
# 8                      15.7                       16                     14.5
# 9                      15.9                     15.5                     14.1
# 10                     14.5                     16.4                     13.6
# 11                     15.1                     16.4                     12.1
# ...

# %%
data['Total Station Load (MVA)'].to_excel('august_load.xlsx')

# %%
january_load = pd.read_excel('total station load.xlsx')

# %%
january_load
# Out:
#      Hour     1     2     3     4     5     6     7     8     9  ...    22  \
# 0    1.00  39.7  23.6  28.0  34.8  31.8  32.3  32.6  34.3  34.4  ...  37.4
# 1    2.00  38.8  23.5  27.2  34.2  30.7  31.6  30.7  33.2  33.8  ...  36.0
# 2    3.00  38.1  23.0  26.6  32.6  30.4  31.3  30.8  32.8  33.4  ...  35.2
# 3    4.00  37.7  23.3  26.0  30.2  30.7  31.6  30.5  32.8  32.4  ...  35.0
# 4    5.00  38.9  24.0  26.0  31.3  31.2  32.0  30.9  33.9  32.4  ...  36.8
# 5    6.00  42.5  24.4  26.4  32.3  31.3  33.9  32.2  36.2  34.1  ...  40.4
# 6    7.00  35.6  24.0  24.8  30.2  29.0  35.9  31.2  34.7  33.0  ...  32.0
# 7    8.00  32.5  24.1  23.7  29.9  28.8  34.1  30.6  32.9  32.4  ...  29.3
# 8    9.00  32.4   0.0  19.1  30.5  11.5  11.9  30.1  32.9  32.0  ...  30.0
# 9   10.00  33.3   0.0  30.6  31.5  11.4  10.7  29.7  31.0  32.5  ...  30.5
# 10  11.00  33.7   9.2  30.4  31.4  11.7  10.7  27.4  32.6  32.7  ...  31.0
# ...

# %%
df = {}
for i in range(1,32):
    frame = {'Day'}
    df[i] = pd.concat([january_load[['Hour',i]],i])
# Out:
# -----------------------------------------------------------
# TypeError                 Traceback (most recent call last)
# <ipython-input-83-4824559a22f6> in <module>
#       2 for i in range(1,32):
#       3
# ----> 4     df[i] = pd.concat([january_load[['Hour',i]],i])
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     253         verify_integrity=verify_integrity,
#     254         copy=copy,
# --> 255         sort=sort,
#     256     )
#     257
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     330                     " only Series and DataFrame objs are valid".format(type(obj))
#     331                 )
# --> 332                 raise TypeError(msg)
#     333
#     334             # consolidate
#
# ...

# %%
df[31]
# Out:
#      Hour    31
# 0    1.00  42.4
# 1    2.00  41.3
# 2    3.00  40.4
# 3    4.00  42.1
# 4    5.00  42.2
# 5    6.00  42.1
# 6    7.00  35.0
# 7    8.00  31.6
# 8    9.00  32.5
# 9   10.00  33.0
# 10  11.00  33.8
# 11  12.00  33.6
# 12  13.00  33.6
# 13  14.00  33.6
# 14  15.00  34.8
# 15  16.00  36.4
# 16  17.00  36.3
# 17  18.00  38.6
# 18  18.15  40.3
# 19  18.30  43.4
# 20  18.45  45.9
# 21  19.00  47.3
# 22  19.15  48.3
# 23  19.30  48.0
# 24  19.45  48.2
# 25  20.00  47.4
# 26  20.15  48.3
# 27  21.00  47.5
# 28  22.00  46.7
# 29  23.00  43.8
# 30  24.00  41.4

# %%
pd.concat([df[1], df[2]])
# Out:
# /home/ghaff/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#      Hour     1     2
# 0    1.00  39.7   NaN
# 1    2.00  38.8   NaN
# 2    3.00  38.1   NaN
# 3    4.00  37.7   NaN
# 4    5.00  38.9   NaN
# ..    ...   ...   ...
# 26  20.15   NaN  33.0
# 27  21.00   NaN  33.2
# 28  22.00   NaN  31.3
# 29  23.00   NaN  31.1
# 30  24.00   NaN  30.8
#
# [62 rows x 3 columns]
